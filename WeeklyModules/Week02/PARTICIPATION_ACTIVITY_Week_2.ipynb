# %% [markdown]
# <a href="https://colab.research.google.com/github/239-blip/mssp607/blob/main/WeeklyModules/Week02/PARTICIPATION_ACTIVITY_Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2. Show the code in a Notebook cell:
#
# a.  Create a variable called 'spam' that contains [2, 4, 6, 8, 10].
#
# b.  Assign the value of 'hello' as the third value in a list stored in a variable named 'spam.'

# %%
spam=[2, 4, 6, 8, 10]
spam[2]='hello'
print(spam)
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# 3. Show the code in a new cell:
#
# a. Create a variable called 'letters' that contains ['a',  'b',  'c', 'd'].
#
# b. What does letters[int(int('3'*2)//11)] evaluate to? Explain why in a comment.
#
# c. What does letters[-1] evaluate to? Explain why in a comment.
#
# d. What does letters[:2] evaluate to? Explain why in a comment.

# %%
letters=['a', 'b', 'c', 'd']
letters[int(int('3'*2)//11)] #'d'. '3'*2=='33', int('33')==33, 33//11==3, thus the result is letters[3] which is 'd'
letters[-1] #'d'. the index -1 refers to the last element in the list letters
letters[:2] #['a', 'b']. ":2" refers to the first two elements in the list
# Out:
# ['a', 'b']

# %% [markdown]
# 4. How can you get the tuple form of the value of a list? How can you get the lists from a tuple? Show a code example in a new cell in the Notebook.

# %%
list1=[1,2,3,4]
tuple1=tuple(list1)
print(tuple1)

list2=list(tuple1)
print(list2)
# Out:
# (1, 2, 3, 4)
# [1, 2, 3, 4]

# %% [markdown]
# 5. Practice program (see Sweigart, Chapter Four, Comma Code Practice Project:
#
# a. spam = ['apples', 'bananas', 'tofu', 'cats']
#
# Write a function that accepts the list 'spam' as an argument and returns a string with all the items separated by a comma and a space, with 'and' inserted before the last item. The function should work with any list.

# %%
spam = ['apples', 'bananas', 'tofu', 'cats']
def seplist(i):
  if len(i)==0:
    return ''
  if len(i)==1:
    return i[0]
  newlist=''
  for n in range(len(i)-1):
    newlist+=i[n]+', '
  newlist+='and '+i[-1]
  return newlist
print(seplist(spam))
# Out:
# apples, bananas, tofu, and cats

# %% [markdown]
# 3. Answer the following questions:
#
# a. When does the code in a function execute: when the function is defined or called?
#
# b. How many global scopes are there in a Python program? How many local scopes?
#
# c. What happens to variables in a local scope when the function call returns?
#
# d. How can you prevent a program from crashing when it gets an error?

# %%
#a. When the function is called.
#b. There can be only one global scope, but local scopes can have many.
#c. The varlibles in a local scope will be destroyed and forgotten when the function call returens.
#d. By using "try" and "except" statements.

# %% [markdown]
# Practice Program

# %%
print("Please enter an integer:")
number=int(input(">"))

def collatz(number):
  if number%2==0:  #If number is even
    i=number//2
  else:
    i=3*number+1
  print(i,end=" ")
  return i

while number!=1:
  number=collatz(number)   #Keep calling collatz()
# Out:
# Please enter an integer:
# >3
# 10 5 16 8 4 2 1
